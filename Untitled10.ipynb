# %%
# !pip install numpy
# !pip install tensorflow
# !pip install sklearn
# Out:
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import numpy as np
import tensorflow as tf

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet import preprocess_input, decode_predictions

# %% [markdown]
# подготавливаем даталоудеры формат папок
# # dataset/
# # ├── cats/
# # │   ├── cat1.jpg
# # │   └── cat2.jpg
# # └── dogs/
# #     ├── dog1.jpg
# #     └── dog2.jpg
# можем писать rescale=1./255 вместо preprocessing_function=preprocess_input но только для реснет

# %%
train_gen = ImageDataGenerator(preprocessing_function=preprocess_input, validation_split=0.2).flow_from_directory('/content/drive/MyDrive/archive/train', target_size=(224,224), batch_size=32, subset='training')
val_gen = ImageDataGenerator(preprocessing_function=preprocess_input, validation_split=0.2).flow_from_directory('/content/drive/MyDrive/archive/test', target_size=(224,224), batch_size=32, subset='validation')
# Out:
# Found 1913 images belonging to 4 classes.
# Found 38 images belonging to 4 classes.

# %% [markdown]
# Загружаем модель нейронка рекомендует EfficientNetB0

# %%
base = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224,224,3))
base.trainable = False

# %%
model = tf.keras.Sequential([base, GlobalAveragePooling2D(), Dense(train_gen.num_classes, activation='softmax')])

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(train_gen, validation_data=val_gen, epochs=10)
# Out:
# Epoch 1/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 659s 11s/step - accuracy: 0.7642 - loss: 0.6659 - val_accuracy: 0.9737 - val_loss: 0.2340
# Epoch 2/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 203ms/step - accuracy: 0.8996 - loss: 0.3193 - val_accuracy: 0.9737 - val_loss: 0.1296
# Epoch 3/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 207ms/step - accuracy: 0.9216 - loss: 0.2538 - val_accuracy: 0.9737 - val_loss: 0.0914
# Epoch 4/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 13s 210ms/step - accuracy: 0.9341 - loss: 0.2070 - val_accuracy: 0.9737 - val_loss: 0.0733
# Epoch 5/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 13s 207ms/step - accuracy: 0.9456 - loss: 0.1815 - val_accuracy: 1.0000 - val_loss: 0.0600
# Epoch 6/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 13s 217ms/step - accuracy: 0.9550 - loss: 0.1627 - val_accuracy: 0.9737 - val_loss: 0.0531
# Epoch 7/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 206ms/step - accuracy: 0.9545 - loss: 0.1529 - val_accuracy: 1.0000 - val_loss: 0.0467
# Epoch 8/10
# ...

# %%
labels_dict = train_gen.class_indices

# Получить просто список названий в правильном порядке
class_names = list(labels_dict.keys())

print(class_names)
# Out:
# ['Bacterial Leaf Disease', 'Dried Leaf', 'Fungal Brown Spot Disease', 'Healthy Leaf']

# %% [markdown]
# Проверка на изображении

# %%
img = tf.keras.utils.load_img('/content/21.jfif', target_size=(224, 224))
img_array = tf.keras.utils.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = preprocess_input(img_array)

# %%
predictions = model.predict(img_array, verbose=0)[0]
class_idx = np.argmax(predictions)
confidence = predictions[class_idx]

# %%
class_idx
# Out:
# np.int64(3)

# %%
class_names[class_idx]
# Out:
# 'Healthy Leaf'

# %% [markdown]
# Сохранение модели

# %%
model.save('/content/my_model.keras')

# %% [markdown]
# Загрузка и использование модели

# %%
from tensorflow.keras.models import load_model
model_1 = load_model('/content/my_model.keras')
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 4 variables whereas the saved optimizer has 6 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %% [markdown]
# если хочешь продолжить обучение

# %%
model_1.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# EfficientNetB3~12 млнУниверсальный выбор300x300 можно попробывать
